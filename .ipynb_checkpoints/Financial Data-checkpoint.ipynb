# %%
import pandas as pd
import numpy as np
import requests as req
import sys
key = "UADYC1EWP37WBZQO"

# %%
# list of nyse companies
nyse = pd.DataFrame(pd.read_csv("nyse.csv"))
nyse = nyse[["Symbol","Name","MarketCap","Sector","industry"]]
len(nyse)
# Out:
# 3143

# %%
# list of nasdaq companies
nasdaq = pd.DataFrame(pd.read_csv("nasdaq.csv"))
nasdaq = nasdaq[["Symbol","Name","MarketCap","Sector","industry"]]
len(nasdaq)
# Out:
# 3280

# %%
# list of amex companies
amex = pd.DataFrame(pd.read_csv("amex.csv"))
amex = amex[["Symbol","Name","MarketCap","Sector","industry"]]
amex["Symbol"] = amex["Symbol"].str.strip()
amex
# Out:
#      Symbol                                               Name MarketCap  \
# 0      XXII                            22nd Century Group, Inc  $316.32M
# 1       FAX              Aberdeen Asia-Pacific Income Fund Inc    $1.23B
# 2       IAF                 Aberdeen Australia Equity Fund Inc  $147.37M
# 3        CH                          Aberdeen Chile Fund, Inc.   $83.84M
# 4       ABE  Aberdeen Emerging Markets Smaller Company Oppo...  $135.35M
# 5       FCO                  Aberdeen Global Income Fund, Inc.   $79.57M
# 6        IF                      Aberdeen Indonesia Fund, Inc.   $69.98M
# 7       ISL                         Aberdeen Israel Fund, Inc.   $79.86M
# 8       ACU                           Acme United Corporation.   $78.78M
# 9      ATNM                     Actinium Pharmaceuticals, Inc.   $52.38M
# 10       AE                     Adams Resources & Energy, Inc.  $194.01M
# 11      ACY                                  AeroCentury Corp.   $20.68M
# 12     AIRI                               Air Industries Group   $38.53M
# 13      AXU                               Alexco Resource Corp  $155.92M
# 14      ALO                                     Alio Gold Inc.  $155.04M
# 15      AAU                             Almaden Minerals, Ltd.  $100.32M
# 16      APT                               Alpha Pro Tech, Ltd.   $60.62M
# 17     AAMC                   Altisource Asset Management Corp  $130.71M
# 18      DIT                         AMCON Distributing Company   $62.16M
# 19      ALN                        American Lorain Corporation    $6.62M
# 20      AMS                  American Shared Hospital Services   $14.28M
# 21     USAS                        Americas Silver Corporation  $153.54M
# 22     AMPE                        Ampio Pharmaceuticals, Inc.  $216.43M
# 23     APHB                   AmpliPhi Biosciences Corporation    $9.31M
# 24    ARNC^                                       Arconic Inc.       n/a
# 25      AKG                                   Asanko Gold Inc.  $125.79M
# 26     AINC                                       Ashford Inc.  $206.13M
# 27   ASB.WS                               Associated Banc-Corp       n/a
# 28      AST                     Asterias Biotherapeutics, Inc.  $116.42M
# 29      AUG                               Auryn Resources Inc.  $105.18M
# ..      ...                                                ...       ...
# 328     GGO                      The Gabelli Go Anywhere Trust   $29.05M
# 329   GGO^A                      The Gabelli Go Anywhere Trust       n/a
# 330     TMP                     Tompkins Financial Corporation    $1.26B
# 331     TAT                        Transatlantic Petroleum Ltd   $50.32M
# 332    TRXC                                 TransEnterix, Inc.  $404.46M
# 333     TMQ                                Trilogy Metals Inc.  $119.42M
# 334    TPHS                        Trinity Place Holdings Inc.  $213.87M
# 335     TRT                            Trio-Tech International   $24.13M
# 336     HTM                               U.S. Geothermal Inc.   $64.19M
# 341       Basic Industries                                    Precious Metals
# 342       Basic Industries                                    Precious Metals
# 343      Consumer Durables                       Telecommunications Equipment
# 344          Miscellaneous                             Multi-Sector Companies
# 345       Basic Industries                                    Precious Metals
# 346            Health Care  Biotechnology: In Vitro & In Vivo Diagnostic S...
# 347             Technology                              Professional Services
# 348                    n/a                                                n/a
# 349                    n/a                                                n/a
# 350                    n/a                                                n/a
# 351       Basic Industries                                    Precious Metals
# 352             Technology                                       EDP Services
# 353          Capital Goods                                Electrical Products
# 354            Health Care  Biotechnology: Biological Products (No Diagnos...
# 355                 Energy                               Oil & Gas Production
# 356             Technology            Computer Software: Prepackaged Software
# 357            Health Care                              Major Pharmaceuticals
#
# [358 rows x 5 columns]

# %%
# amex monthly data api call
date=[]
monthly_open=[]
monthly_close=[]
ticker=[]
counter=0
for index, row in amex.iterrows():
    url = "https://www.alphavantage.co/query?"
    counter=counter+1
    function = "TIME_SERIES_MONTHLY"
    symbol = row["Symbol"]
    target_url = url+"function="+function+"&symbol="+symbol+"&apikey="+key
    print(symbol)
    print(counter)
    print("______________________________________________________________________")
    print(target_url)
    limit=0
    try:
        info = req.get(target_url).json()
        while limit <= 60:
            for item in info["Monthly Time Series"]: 
                    ticker.append(symbol)
                    date.append(item)
                    monthly_open.append(info["Monthly Time Series"][item]["1. open"])
                    monthly_close.append(info["Monthly Time Series"][item]["4. close"])
                    limit = limit+ 1
    except KeyError:
        pass
    except KeyboardInterrupt:
        raise
# Out:
# XXII
# 1
# ______________________________________________________________________
# https://www.alphavantage.co/query?function=TIME_SERIES_MONTHLY&symbol=XXII&apikey=UADYC1EWP37WBZQO
# FAX
# 2
# ______________________________________________________________________
# https://www.alphavantage.co/query?function=TIME_SERIES_MONTHLY&symbol=FAX&apikey=UADYC1EWP37WBZQO
# IAF
# 3
# ______________________________________________________________________
# https://www.alphavantage.co/query?function=TIME_SERIES_MONTHLY&symbol=IAF&apikey=UADYC1EWP37WBZQO
# CH
# 4
# ______________________________________________________________________
# https://www.alphavantage.co/query?function=TIME_SERIES_MONTHLY&symbol=CH&apikey=UADYC1EWP37WBZQO
# ABE
# 5
# ______________________________________________________________________
# https://www.alphavantage.co/query?function=TIME_SERIES_MONTHLY&symbol=ABE&apikey=UADYC1EWP37WBZQO
# FCO
# 6
# ______________________________________________________________________
# https://www.alphavantage.co/query?function=TIME_SERIES_MONTHLY&symbol=FCO&apikey=UADYC1EWP37WBZQO
# IF
# 7
# ______________________________________________________________________
# https://www.alphavantage.co/query?function=TIME_SERIES_MONTHLY&symbol=IF&apikey=UADYC1EWP37WBZQO
# ISL
# 8
# ______________________________________________________________________
# https://www.alphavantage.co/query?function=TIME_SERIES_MONTHLY&symbol=ISL&apikey=UADYC1EWP37WBZQO
# ACU
# 9
# ______________________________________________________________________
# https://www.alphavantage.co/query?function=TIME_SERIES_MONTHLY&symbol=ACU&apikey=UADYC1EWP37WBZQO
# ATNM
# 10
# ______________________________________________________________________
# https://www.alphavantage.co/query?function=TIME_SERIES_MONTHLY&symbol=ATNM&apikey=UADYC1EWP37WBZQO
# AE
# 11
# ______________________________________________________________________
# https://www.alphavantage.co/query?function=TIME_SERIES_MONTHLY&symbol=AE&apikey=UADYC1EWP37WBZQO
# ACY
# 12
# ______________________________________________________________________
# https://www.alphavantage.co/query?function=TIME_SERIES_MONTHLY&symbol=ACY&apikey=UADYC1EWP37WBZQO
# AIRI
# 13
# ______________________________________________________________________
# https://www.alphavantage.co/query?function=TIME_SERIES_MONTHLY&symbol=AIRI&apikey=UADYC1EWP37WBZQO
# AXU
# 14
# ______________________________________________________________________
# https://www.alphavantage.co/query?function=TIME_SERIES_MONTHLY&symbol=AXU&apikey=UADYC1EWP37WBZQO
# ALO
# 15
# ______________________________________________________________________
# https://www.alphavantage.co/query?function=TIME_SERIES_MONTHLY&symbol=ALO&apikey=UADYC1EWP37WBZQO
# AAU
# 16
# ______________________________________________________________________
# https://www.alphavantage.co/query?function=TIME_SERIES_MONTHLY&symbol=AAU&apikey=UADYC1EWP37WBZQO
# APT
# 17
# ______________________________________________________________________
# https://www.alphavantage.co/query?function=TIME_SERIES_MONTHLY&symbol=APT&apikey=UADYC1EWP37WBZQO
# AAMC
# 18
# ______________________________________________________________________
# https://www.alphavantage.co/query?function=TIME_SERIES_MONTHLY&symbol=AAMC&apikey=UADYC1EWP37WBZQO
# DIT
# 19
# ______________________________________________________________________
# https://www.alphavantage.co/query?function=TIME_SERIES_MONTHLY&symbol=DIT&apikey=UADYC1EWP37WBZQO
# ALN
# 20
# ______________________________________________________________________
# https://www.alphavantage.co/query?function=TIME_SERIES_MONTHLY&symbol=ALN&apikey=UADYC1EWP37WBZQO
# AMS
# 21
# ______________________________________________________________________
# https://www.alphavantage.co/query?function=TIME_SERIES_MONTHLY&symbol=AMS&apikey=UADYC1EWP37WBZQO
# USAS
# 22
# ______________________________________________________________________
# https://www.alphavantage.co/query?function=TIME_SERIES_MONTHLY&symbol=USAS&apikey=UADYC1EWP37WBZQO
# AMPE
# 23
# ______________________________________________________________________
# https://www.alphavantage.co/query?function=TIME_SERIES_MONTHLY&symbol=AMPE&apikey=UADYC1EWP37WBZQO
# APHB
# 24
# ______________________________________________________________________
# https://www.alphavantage.co/query?function=TIME_SERIES_MONTHLY&symbol
# ______________________________________________________________________
# https://www.alphavantage.co/query?function=TIME_SERIES_MONTHLY&symbol=UFAB&apikey=UADYC1EWP37WBZQO
# UAMY
# 339
# ______________________________________________________________________
# https://www.alphavantage.co/query?function=TIME_SERIES_MONTHLY&symbol=UAMY&apikey=UADYC1EWP37WBZQO
# UUU
# 340
# ______________________________________________________________________
# https://www.alphavantage.co/query?function=TIME_SERIES_MONTHLY&symbol=UUU&apikey=UADYC1EWP37WBZQO
# UQM
# 341
# ______________________________________________________________________
# https://www.alphavantage.co/query?function=TIME_SERIES_MONTHLY&symbol=UQM&apikey=UADYC1EWP37WBZQO
# URG
# 342
# ______________________________________________________________________
# https://www.alphavantage.co/query?function=TIME_SERIES_MONTHLY&symbol=URG&apikey=UADYC1EWP37WBZQO
# UEC
# 343
# ______________________________________________________________________
# https://www.alphavantage.co/query?function=TIME_SERIES_MONTHLY&symbol=UEC&apikey=UADYC1EWP37WBZQO
# VII
# 344
# ______________________________________________________________________
# https://www.alphavantage.co/query?function=TIME_SERIES_MONTHLY&symbol=VII&apikey=UADYC1EWP37WBZQO
# VHC
# 345
# ______________________________________________________________________
# https://www.alphavantage.co/query?function=TIME_SERIES_MONTHLY&symbol=VHC&apikey=UADYC1EWP37WBZQO
# VGZ
# 346
# ______________________________________________________________________
# https://www.alphavantage.co/query?function=TIME_SERIES_MONTHLY&symbol=VGZ&apikey=UADYC1EWP37WBZQO
# VNRX
# 347
# ______________________________________________________________________
# https://www.alphavantage.co/query?function=TIME_SERIES_MONTHLY&symbol=VNRX&apikey=UADYC1EWP37WBZQO
# VISI
# 348
# ______________________________________________________________________
# https://www.alphavantage.co/query?function=TIME_SERIES_MONTHLY&symbol=VISI&apikey=UADYC1EWP37WBZQO
# EAD
# 349
# ______________________________________________________________________
# https://www.alphavantage.co/query?function=TIME_SERIES_MONTHLY&symbol=EAD&apikey=UADYC1EWP37WBZQO
# ERC
# 350
# ______________________________________________________________________
# https://www.alphavantage.co/query?function=TIME_SERIES_MONTHLY&symbol=ERC&apikey=UADYC1EWP37WBZQO
# ERH
# 351
# ______________________________________________________________________
# https://www.alphavantage.co/query?function=TIME_SERIES_MONTHLY&symbol=ERH&apikey=UADYC1EWP37WBZQO
# WRN
# 352
# ______________________________________________________________________
# https://www.alphavantage.co/query?function=TIME_SERIES_MONTHLY&symbol=WRN&apikey=UADYC1EWP37WBZQO
# WYY
# 353
# ______________________________________________________________________
# https://www.alphavantage.co/query?function=TIME_SERIES_MONTHLY&symbol=WYY&apikey=UADYC1EWP37WBZQO
# WTT
# 354
# ______________________________________________________________________
# https://www.alphavantage.co/query?function=TIME_SERIES_MONTHLY&symbol=WTT&apikey=UADYC1EWP37WBZQO
# XTNT
# 355
# ______________________________________________________________________
# https://www.alphavantage.co/query?function=TIME_SERIES_MONTHLY&symbol=XTNT&apikey=UADYC1EWP37WBZQO
# YUMA
# 356
# ______________________________________________________________________
# https://www.alphavantage.co/query?function=TIME_SERIES_MONTHLY&symbol=YUMA&apikey=UADYC1EWP37WBZQO
# ZDGE
# 357
# ______________________________________________________________________
# https://www.alphavantage.co/query?function=TIME_SERIES_MONTHLY&symbol=ZDGE&apikey=UADYC1EWP37WBZQO
# ZOM
# 358
# ______________________________________________________________________
# https://www.alphavantage.co/query?function=TIME_SERIES_MONTHLY&symbol=ZOM&apikey=UADYC1EWP37WBZQO

# %%
# finding the earnings per share

actual_eps = [] 
estimated_eps = []
fiscal_period = []
stock_ticker = []
counter = 0
for index, row in amex.iterrows():
    counter = counter + 1
    symbol = row["Symbol"]
    url = "https://api.iextrading.com/1.0/stock/"+symbol+"/earnings"
    print(counter)
    print(symbol)
    print(url)
    try:
        info = req.get(url).json()
        for x in range(0,4):
            stock_ticker.append(symbol)
            actual_eps.append(info["earnings"][x]["actualEPS"])
            estimated_eps.append(info["earnings"][x]["estimatedEPS"])
            fiscal_period.append(info["earnings"][x]["fiscalPeriod"])
    except:
        pass
# Out:
# 1
# XXII
# https://api.iextrading.com/1.0/stock/XXII/earnings
# 2
# FAX
# https://api.iextrading.com/1.0/stock/FAX/earnings
# 3
# IAF
# https://api.iextrading.com/1.0/stock/IAF/earnings
# 4
# CH
# https://api.iextrading.com/1.0/stock/CH/earnings
# 5
# ABE
# https://api.iextrading.com/1.0/stock/ABE/earnings
# 6
# FCO
# https://api.iextrading.com/1.0/stock/FCO/earnings
# 7
# IF
# https://api.iextrading.com/1.0/stock/IF/earnings
# 8
# ISL
# https://api.iextrading.com/1.0/stock/ISL/earnings
# 9
# ACU
# https://api.iextrading.com/1.0/stock/ACU/earnings
# 10
# ATNM
# https://api.iextrading.com/1.0/stock/ATNM/earnings
# 11
# AE
# https://api.iextrading.com/1.0/stock/AE/earnings
# 12
# ACY
# https://api.iextrading.com/1.0/stock/ACY/earnings
# 13
# AIRI
# https://api.iextrading.com/1.0/stock/AIRI/earnings
# 14
# AXU
# https://api.iextrading.com/1.0/stock/AXU/earnings
# 15
# ALO
# https://api.iextrading.com/1.0/stock/ALO/earnings
# 16
# AAU
# https://api.iextrading.com/1.0/stock/AAU/earnings
# 17
# APT
# https://api.iextrading.com/1.0/stock/APT/earnings
# 18
# AAMC
# https://api.iextrading.com/1.0/stock/AAMC/earnings
# 19
# DIT
# https://api.iextrading.com/1.0/stock/DIT/earnings
# 20
# ALN
# https://api.iextrading.com/1.0/stock/ALN/earnings
# 21
# AMS
# https://api.iextrading.com/1.0/stock/AMS/earnings
# 22
# USAS
# https://api.iextrading.com/1.0/stock/USAS/earnings
# 23
# AMPE
# https://api.iextrading.com/1.0/stock/AMPE/earnings
# 24
# APHB
# https://api.iextrading.com/1.0/stock/APHB/earnings
# 25
# ARNC^
# https://api.iextrading.com/1.0/stock/ARNC^/earnings
# 26
# AKG
# https://api.iextrading.com/1.0/stock/AKG/earnings
# 27
# AINC
# https://api.iextrading.com/1.0/stock/AINC/earnings
# 28
# ASB.WS
# https://api.iextrading.com/1.0/stock/ASB.WS/earnings
# 29
# AST
# https://api.iextrading.com/1.0/stock/AST/earnings
# 30
# AUG
# https://api.iextrading.com/1.0/stock/AUG/earnings
# 31
# AWX
# https://api.iextrading.com/1.0/stock/AWX/earnings
# 32
# ASM
# https://api.iextrading.com/1.0/stock/ASM/earnings
# 33
# BTG
# https://api.iextrading.com/1.0/stock/BTG/earnings
# 34
# BTN
# https://api.iextrading.com/1.0/stock/BTN/earnings
# 35
# BKJ
# https://api.iextrading.com/1.0/stock/BKJ/earnings
# 36
# BCV
# https://api.iextrading.com/1.0/stock/BCV/earnings
# 37
# BCV^A
# https://api.iextrading.com/1.0/stock/BCV^A/earnings
# 38
# BAA
# https://api.iextrading.com/1.0/stock/BAA/earnings
# 39
# BHB
# https://api.iextrading.com/1.0/stock/BHB/earnings
# 40
# BRN
# https://api.iextrading.com/1.0/stock/BRN/earnings
# 41
# BGSF
# https://api.iextrading.com/1.0/stock/BGSF/earnings
# 42
# BPMX
# https://api.iextrading.com/1.0/stock/BPMX/earnings
# 43
# BTX
# https://api.iextrading.com/1.0/stock/BTX/earnings
# 44
# BTX.WS
# https://api.iextrading.com/1.0/stock/BTX.WS/earnings
# 45
# BGI
# https://api.iextrading.com/1.0/stock/BGI/earnings
# 46
# BZM
# https://api.iextrading.com/1.0/stock/BZM/earnings
# 47
# MHE
# https://api.iextrading.com/1.0/stock/MHE/earnings
# 48
# BLE
# https://api.iextrading.com/1.0/stock/BLE/earnings
# 49
# BLJ
# https://api.iextrading.com/1.0/stock/BLJ/earnings
# 50
# BFY
# https://api.iextrading.com/1.0/stock/BFY/earnings
# 51
# BHV
# https://api.iextrading.com/1.0/stock/BHV/earnings
# 52
# BDR
# https://api.iextrading.com/1.0/stock/BDR/earnings
# 53
# BRG
# https://api.iextrading.com/1.0/stock/BRG/earnings
# 54
# BRG^A
# https://api.iextrading.com/1.0/stock/BRG^A/earnings
# 55
# BRG^C
# https://api.iextrading.com/1.0/stock/BRG^C/earnings
# 56
# BRG^D
# https://api.iextrading.com/1.0/stock/BRG^D/earnings
# 57
# BVX
# https://api.iextrading.com/1.0/stock/BVX/earnings
# 58
# BWL.A
# https://api.iextrading.com/1.0/stock/BWL.A/earnings
# 59
# CMCL
# https://api.iextrading.com/1.0/stock/CMCL/earnings
# 60
# CEI
# https://api.iextrading.com/1.0/stock/CEI/earnings
# 61
# CANF
# https://api.iextrading.com/1.0/stock/CANF/earnings
# 62
# ROX
# https://api.iextrading.com/1.0/stock/ROX/earnings
# 63
# CAW
# https://api.iextrading.com/1.0/stock/CAW/earnings
# 64
# CVM
# https://api.iextrading.com/1.0/stock/CVM/earnings
# 65
# CVM.WS
# https://api.iextrading.com/1.0/stock/CVM.WS/earnings
# 66
# CEF
# https://api.iextrading.com/1.0/stock/CEF/earnings
# 67
# CET
# https://api.iextrading.com/1.0/stock/CET/earnings
# 68
# LEU
# https://api.iextrading.com/1.0/stock/LEU/earnings
# 69
# CCF
# https://api.iextrading.com/1.0/stock/CCF/earnings
# 70
# CQH
# https://api.iextrading.com/1.0/stock/CQH/earnings
# 71
# CQP
# https://api.iextrading.com/1.0/stock/CQP/earnings
# 72
# LNG
# https://api.iextrading.com/1.0/stock/LNG/earnings
# 73
# CVR
# https://api.iextrading.com/1.0/stock/CVR/earnings
# 74
# CPHI
# https://api.iextrading.com/1.0/stock/CPHI/earnings
# 75
# CISN.WS
# https://api.iextrading.com/1.0/stock/CISN.WS/earnings
# 76
# CKX
# https://api.iextrading.com/1.0/stock/CKX/earnings
# 77
# GLV
# https://api.iextrading.com/1.0/stock/GLV/earnings
# 78
# GLQ
# https://api.iextrading.com/1.0/stock/GLQ/earnings
# 79
# GLO
# https://api.iextrading.com/1.0/stock/GLO/earnings
# 80
# COHN
# https://api.iextrading.com/1.0/stock/COHN/earnings
# 81
# MOC
# https://api.iextrading.com/1.0/stock/MOC/earnings
# 82
# CIX
# https://api.iextrading.com/1.0/stock/CIX/earnings
# 83
# LODE
# https://api.iextrading.com/1.0/stock/LODE/earnings
# 84
# CDOR
# https://api.iextrading.com/1.0/stock/CDOR/earnings
# 85
# CTO
# https://api.iextrading.com/1.0/stock/CTO/earnings
# 86
# MCF
# https://api.iextrading.com/1.0/stock/MCF/earnings
# 87
# CUO
# https://api.iextrading.com/1.0/stock/CUO/earnings
# 88
# CMT
# https://api.iextrading.com/1.0/stock/CMT/earnings
# 89
# CVRS
# https://api.iextrading.com/1.0/stock/CVRS/earnings
# 90
# CRMD
# https://api.iextrading.com/1.0/stock/CRMD/earnings
# 91
# CRF
# https://api.iextrading.com/1.0/stock/CRF/earnings
# 92
# CLM
# https://api.iextrading.com/1.0/stock/CLM/earnings
# 93
# CVU
# https://api.iextrading.com/1.0/stock/CVU/earnings
# 94
# CIK
# https://api.iextrading.com/1.0/stock/CIK/earnings
# 95
# DHY
# https://api.iextrading.com/1.0/stock/DHY/earnings
# 96
# CRHM
# https://api.iextrading.com/1.0/stock/CRHM/earnings
# 97
# CRVP
# https://api.iextrading.com/1.0/stock/CRVP/earnings
# 98
# CTEK
# https://api.iextrading.com/1.0/stock/CTEK/earnings
# 99
# DXR
# https://api.iextrading.com/1.0/stock/DXR/earnings
# 100
# VCF
# https://api.iextrading.com/1.0/stock/VCF/earnings
# 101
# VFL
# https://api.iextrading.com/1.0/stock/VFL/earnings
# 102
# VMM
# https://api.iextrading.com/1.0/stock/VMM/earnings
# 103
# DLA
# https://api.iextrading.com/1.0/stock/DLA/earnings
# 104
# DNN
# https://api.iextrading.com/1.0/stock/DNN/earnings
# 105
# DGSE
# https://api.iextrading.com/1.0/stock/DGSE/earnings
# 106
# DPW
# https://api.iextrading.com/1.0/stock/DPW/earnings
# 107
# DSS
# https://api.iextrading.com/1.0/stock/DSS/earnings
# 108
# DMF
# https://api.iextrading.com/1.0/stock/DMF/earnings
# 109
# GRF
# https://api.iextrading.com/1.0/stock/GRF/earnings
# 110
# EVM
# https://api.iextrading.com/1.0/stock/EVM/earnings
# 111
# EIA
# https://api.iextrading.com/1.0/stock/EIA/earnings
# 112
# CEV
# https://api.iextrading.com/1.0/stock/CEV/earnings
# 113
# EVV
# https://api.iextrading.com/1.0/stock/EVV/earnings
# 114
# MAB
# https://api.iextrading.com/1.0/stock/MAB/earnings
# 115
# MMV
# https://api.iextrading.com/1.0/stock/MMV/earnings
# 116
# MIW
# https://api.iextrading.com/1.0/stock/MIW/earnings
# 117
# EMI
# https://api.iextrading.com/1.0/stock/EMI/earnings
# 118
# EIM
# https://api.iextrading.com/1.0/stock/EIM/earnings
# 119
# EIV
# https://api.iextrading.com/1.0/stock/EIV/earnings
# 120
# EMJ
# https://api.iextrading.com/1.0/stock/EMJ/earnings
# 121
# EVJ
# https://api.iextrading.com/1.0/stock/EVJ/earnings
# 122
# ENX
# https://api.iextrading.com/1.0/stock/ENX/earnings
# 123
# NYH
# https://api.iextrading.com/1.0/stock/NYH/earnings
# 124
# EVY
# https://api.iextrading.com/1.0/stock/EVY/earnings
# 125
# EIO
# https://api.iextrading.com/1.0/stock/EIO/earnings
# 126
# EVO
# https://api.iextrading.com/1.0/stock/EVO/earnings
# 127
# EIP
# https://api.iextrading.com/1.0/stock/EIP/earnings
# 128
# EVP
# https://api.iextrading.com/1.0/stock/EVP/earnings
# 129
# ELMD
# https://api.iextrading.com/1.0/stock/ELMD/earnings
# 130
# ELLO
# https://api.iextrading.com/1.0/stock/ELLO/earnings
# 131
# ECF
# https://api.iextrading.com/1.0/stock/ECF/earnings
# 132
# ECF^A
# https://api.iextrading.com/1.0/stock/ECF^A/earnings
# 133
# EMAN
# https://api.iextrading.com/1.0/stock/EMAN/earnings
# 134
# MSN
# https://api.iextrading.com/1.0/stock/MSN/earnings
# 135
# EMX
# https://api.iextrading.com/1.0/stock/EMX/earnings
# 136
# UUUU
# https://api.iextrading.com/1.0/stock/UUUU/earnings
# 137
# UUUU.WS
# https://api.iextrading.com/1.0/stock/UUUU.WS/earnings
# 138
# ENRJ
# https://api.iextrading.com/1.0/stock/ENRJ/earnings
# 139
# ENSV
# https://api.iextrading.com/1.0/stock/ENSV/earnings
# 140
# ESNC
# https://api.iextrading.com/1.0/stock/ESNC/earnings
# 141
# EGI
# https://api.iextrading.com/1.0/stock/EGI/earnings
# 142
# EVI
# https://api.iextrading.com/1.0/stock/EVI/earnings
# 143
# ERN
# https://api.iextrading.com/1.0/stock/ERN/earnings
# 144
# ESP
# https://api.iextrading.com/1.0/stock/ESP/earnings
# 145
# EVBN
# https://api.iextrading.com/1.0/stock/EVBN/earnings
# 146
# EPM
# https://api.iextrading.com/1.0/stock/EPM/earnings
# 147
# FEN
# https://api.iextrading.com/1.0/stock/FEN/earnings
# 148
# BDL
# https://api.iextrading.com/1.0/stock/BDL/earnings
# 149
# FSI
# https://api.iextrading.com/1.0/stock/FSI/earnings
# 150
# FTF
# https://api.iextrading.com/1.0/stock/FTF/earnings
# 151
# FSP
# https://api.iextrading.com/1.0/stock/FSP/earnings
# 152
# FRD
# https://api.iextrading.com/1.0/stock/FRD/earnings
# 153
# FTNW
# https://api.iextrading.com/1.0/stock/FTNW/earnings
# 154
# GGN
# https://api.iextrading.com/1.0/stock/GGN/earnings
# 155
# GGN^B
# https://api.iextrading.com/1.0/stock/GGN^B/earnings
# 156
# GST
# https://api.iextrading.com/1.0/stock/GST/earnings
# 157
# GST^A
# https://api.iextrading.com/1.0/stock/GST^A/earnings
# 158
# GST^B
# https://api.iextrading.com/1.0/stock/GST^B/earnings
# 159
# JOB
# https://api.iextrading.com/1.0/stock/JOB/earnings
# 160
# GMO
# https://api.iextrading.com/1.0/stock/GMO/earnings
# 161
# GSB
# https://api.iextrading.com/1.0/stock/GSB/earnings
# 162
# GSAT
# https://api.iextrading.com/1.0/stock/GSAT/earnings
# 163
# GLOW
# https://api.iextrading.com/1.0/stock/GLOW/earnings
# 164
# GORO
# https://api.iextrading.com/1.0/stock/GORO/earnings
# 165
# GSV
# https://api.iextrading.com/1.0/stock/GSV/earnings
# 166
# AUMN
# https://api.iextrading.com/1.0/stock/AUMN/earnings
# 167
# GSS
# https://api.iextrading.com/1.0/stock/GSS/earnings
# 168
# GV
# https://api.iextrading.com/1.0/stock/GV/earnings
# 169
# GDP
# https://api.iextrading.com/1.0/stock/GDP/earnings
# 170
# GTE
# https://api.iextrading.com/1.0/stock/GTE/earnings
# 171
# GPL
# https://api.iextrading.com/1.0/stock/GPL/earnings
# 172
# SIM
# https://api.iextrading.com/1.0/stock/SIM/earnings
# 173
# GVP
# https://api.iextrading.com/1.0/stock/GVP/earnings
# 174
# GLF
# https://api.iextrading.com/1.0/stock/GLF/earnings
# 175
# GLF.WS
# https://api.iextrading.com/1.0/stock/GLF.WS/earnings
# 176
# HEB
# https://api.iextrading.com/1.0/stock/HEB/earnings
# 177
# HCAC
# https://api.iextrading.com/1.0/stock/HCAC/earnings
# 178
# HCAC.U
# https://api.iextrading.com/1.0/stock/HCAC.U/earnings
# 179
# HCAC.WS
# https://api.iextrading.com/1.0/stock/HCAC.WS/earnings
# 180
# HLM^
# https://api.iextrading.com/1.0/stock/HLM^/earnings
# 181
# HMG
# https://api.iextrading.com/1.0/stock/HMG/earnings
# 182
# HUSA
# https://api.iextrading.com/1.0/stock/HUSA/earnings
# 183
# IBIO
# https://api.iextrading.com/1.0/stock/IBIO/earnings
# 184
# IBO
# https://api.iextrading.com/1.0/stock/IBO/earnings
# 185
# IEC
# https://api.iextrading.com/1.0/stock/IEC/earnings
# 186
# IMUC
# https://api.iextrading.com/1.0/stock/IMUC/earnings
# 187
# IMUC.WS
# https://api.iextrading.com/1.0/stock/IMUC.WS/earnings
# 188
# IMH
# https://api.iextrading.com/1.0/stock/IMH/earnings
# 189
# IMO
# https://api.iextrading.com/1.0/stock/IMO/earnings
# 190
# IOR
# https://api.iextrading.com/1.0/stock/IOR/earnings
# 191
# IGC
# https://api.iextrading.com/1.0/stock/IGC/earnings
# 192
# INFU
# https://api.iextrading.com/1.0/stock/INFU/earnings
# 193
# IHT
# https://api.iextrading.com/1.0/stock/IHT/earnings
# 194
# NSPR
# https://api.iextrading.com/1.0/stock/NSPR/earnings
# 195
# NSPR.WS
# https://api.iextrading.com/1.0/stock/NSPR.WS/earnings
# 196
# NSPR.WS.B
# https://api.iextrading.com/1.0/stock/NSPR.WS.B/earnings
# 197
# IDN
# https://api.iextrading.com/1.0/stock/IDN/earnings
# 198
# INS
# https://api.iextrading.com/1.0/stock/INS/earnings
# 199
# THM
# https://api.iextrading.com/1.0/stock/THM/earnings
# 200
# INTT
# https://api.iextrading.com/1.0/stock/INTT/earnings
# 201
# INUV
# https://api.iextrading.com/1.0/stock/INUV/earnings
# 202
# VKI
# https://api.iextrading.com/1.0/stock/VKI/earnings
# 203
# ISR
# https://api.iextrading.com/1.0/stock/ISR/earnings
# 204
# ISDR
# https://api.iextrading.com/1.0/stock/ISDR/earnings
# 205
# JRJR
# https://api.iextrading.com/1.0/stock/JRJR/earnings
# 206
# KIQ
# https://api.iextrading.com/1.0/stock/KIQ/earnings
# 207
# KLDX
# https://api.iextrading.com/1.0/stock/KLDX/earnings
# 208
# LTS
# https://api.iextrading.com/1.0/stock/LTS/earnings
# 209
# LTS^A
# https://api.iextrading.com/1.0/stock/LTS^A/earnings
# 210
# LTSL
# https://api.iextrading.com/1.0/stock/LTSL/earnings
# 211
# LAQ
# https://api.iextrading.com/1.0/stock/LAQ/earnings
# 212
# LEVB
# https://api.iextrading.com/1.0/stock/LEVB/earnings
# 213
# LGL
# https://api.iextrading.com/1.0/stock/LGL/earnings
# 214
# LBY
# https://api.iextrading.com/1.0/stock/LBY/earnings
# 215
# LLEX
# https://api.iextrading.com/1.0/stock/LLEX/earnings
# 216
# LIQT
# https://api.iextrading.com/1.0/stock/LIQT/earnings
# 217
# MAG
# https://api.iextrading.com/1.0/stock/MAG/earnings
# 218
# MJCO
# https://api.iextrading.com/1.0/stock/MJCO/earnings
# 219
# MHH
# https://api.iextrading.com/1.0/stock/MHH/earnings
# 220
# MTNB
# https://api.iextrading.com/1.0/stock/MTNB/earnings
# 221
# MNI
# https://api.iextrading.com/1.0/stock/MNI/earnings
# 222
# IPB
# https://api.iextrading.com/1.0/stock/IPB/earnings
# 223
# MXC
# https://api.iextrading.com/1.0/stock/MXC/earnings
# 224
# CCA
# https://api.iextrading.com/1.0/stock/CCA/earnings
# 225
# MICR
# https://api.iextrading.com/1.0/stock/MICR/earnings
# 226
# MLSS
# https://api.iextrading.com/1.0/stock/MLSS/earnings
# 227
# MVF
# https://api.iextrading.com/1.0/stock/MVF/earnings
# 228
# MZA
# https://api.iextrading.com/1.0/stock/MZA/earnings
# 229
# MYO
# https://api.iextrading.com/1.0/stock/MYO/earnings
# 230
# NNVC
# https://api.iextrading.com/1.0/stock/NNVC/earnings
# 231
# ATEST
# https://api.iextrading.com/1.0/stock/ATEST/earnings
# 232
# ATEST.A
# https://api.iextrading.com/1.0/stock/ATEST.A/earnings
# 233
# ATEST.B
# https://api.iextrading.com/1.0/stock/ATEST.B/earnings
# 234
# ATEST.C
# https://api.iextrading.com/1.0/stock/ATEST.C/earnings
# 235
# NHC
# https://api.iextrading.com/1.0/stock/NHC/earnings
# 236
# NAVB
# https://api.iextrading.com/1.0/stock/NAVB/earnings
# 237
# NTIP
# https://api.iextrading.com/1.0/stock/NTIP/earnings
# 238
# NBW
# https://api.iextrading.com/1.0/stock/NBW/earnings
# 239
# NHS
# https://api.iextrading.com/1.0/stock/NHS/earnings
# 240
# NBH
# https://api.iextrading.com/1.0/stock/NBH/earnings
# 241
# NML
# https://api.iextrading.com/1.0/stock/NML/earnings
# 242
# NBO
# https://api.iextrading.com/1.0/stock/NBO/earnings
# 243
# NRO
# https://api.iextrading.com/1.0/stock/NRO/earnings
# 244
# UWN
# https://api.iextrading.com/1.0/stock/UWN/earnings
# 245
# NSU
# https://api.iextrading.com/1.0/stock/NSU/earnings
# 246
# GBR
# https://api.iextrading.com/1.0/stock/GBR/earnings
# 247
# NEN
# https://api.iextrading.com/1.0/stock/NEN/earnings
# 248
# NGD
# https://api.iextrading.com/1.0/stock/NGD/earnings
# 249
# NXE
# https://api.iextrading.com/1.0/stock/NXE/earnings
# 250
# HLTH
# https://api.iextrading.com/1.0/stock/HLTH/earnings
# 251
# NAK
# https://api.iextrading.com/1.0/stock/NAK/earnings
# 252
# NOG
# https://api.iextrading.com/1.0/stock/NOG/earnings
# 253
# NBY
# https://api.iextrading.com/1.0/stock/NBY/earnings
# 254
# NG
# https://api.iextrading.com/1.0/stock/NG/earnings
# 255
# NTN
# https://api.iextrading.com/1.0/stock/NTN/earnings
# 256
# NES
# https://api.iextrading.com/1.0/stock/NES/earnings
# 257
# OCX
# https://api.iextrading.com/1.0/stock/OCX/earnings
# 258
# OGEN
# https://api.iextrading.com/1.0/stock/OGEN/earnings
# 259
# TIS
# https://api.iextrading.com/1.0/stock/TIS/earnings
# 260
# ONP
# https://api.iextrading.com/1.0/stock/ONP/earnings
# 261
# ORM
# https://api.iextrading.com/1.0/stock/ORM/earnings
# 262
# PCG^A
# https://api.iextrading.com/1.0/stock/PCG^A/earnings
# 263
# PCG^B
# https://api.iextrading.com/1.0/stock/PCG^B/earnings
# 264
# PCG^C
# https://api.iextrading.com/1.0/stock/PCG^C/earnings
# 265
# PCG^D
# https://api.iextrading.com/1.0/stock/PCG^D/earnings
# 266
# PCG^E
# https://api.iextrading.com/1.0/stock/PCG^E/earnings
# 267
# PCG^G
# https://api.iextrading.com/1.0/stock/PCG^G/earnings
# 268
# PCG^H
# https://api.iextrading.com/1.0/stock/PCG^H/earnings
# 269
# PCG^I
# https://api.iextrading.com/1.0/stock/PCG^I/earnings
# 270
# PTN
# https://api.iextrading.com/1.0/stock/PTN/earnings
# 271
# PARR
# https://api.iextrading.com/1.0/stock/PARR/earnings
# 272
# PZG
# https://api.iextrading.com/1.0/stock/PZG/earnings
# 273
# TEUM
# https://api.iextrading.com/1.0/stock/TEUM/earnings
# 274
# PRK
# https://api.iextrading.com/1.0/stock/PRK/earnings
# 275
# BTU^
# https://api.iextrading.com/1.0/stock/BTU^/earnings
# 276
# PED
# https://api.iextrading.com/1.0/stock/PED/earnings
# 277
# PFNX
# https://api.iextrading.com/1.0/stock/PFNX/earnings
# 278
# HNW
# https://api.iextrading.com/1.0/stock/HNW/earnings
# 279
# PLG
# https://api.iextrading.com/1.0/stock/PLG/earnings
# 280
# PLYM
# https://api.iextrading.com/1.0/stock/PLYM/earnings
# 281
# PLYM^A
# https://api.iextrading.com/1.0/stock/PLYM^A/earnings
# 282
# PLM
# https://api.iextrading.com/1.0/stock/PLM/earnings
# 283
# PW
# https://api.iextrading.com/1.0/stock/PW/earnings
# 284
# PW^A
# https://api.iextrading.com/1.0/stock/PW^A/earnings
# 285
# PLX
# https://api.iextrading.com/1.0/stock/PLX/earnings
# 286
# RLGT
# https://api.iextrading.com/1.0/stock/RLGT/earnings
# 287
# RLGT^A
# https://api.iextrading.com/1.0/stock/RLGT^A/earnings
# 288
# UTG
# https://api.iextrading.com/1.0/stock/UTG/earnings
# 289
# REED
# https://api.iextrading.com/1.0/stock/REED/earnings
# 290
# RHE
# https://api.iextrading.com/1.0/stock/RHE/earnings
# 291
# RHE^A
# https://api.iextrading.com/1.0/stock/RHE^A/earnings
# 292
# RWC
# https://api.iextrading.com/1.0/stock/RWC/earnings
# 293
# RCG
# https://api.iextrading.com/1.0/stock/RCG/earnings
# 294
# RVP
# https://api.iextrading.com/1.0/stock/RVP/earnings
# 295
# RNN
# https://api.iextrading.com/1.0/stock/RNN/earnings
# 296
# REI
# https://api.iextrading.com/1.0/stock/REI/earnings
# 297
# RIF
# https://api.iextrading.com/1.0/stock/RIF/earnings
# 298
# SACH
# https://api.iextrading.com/1.0/stock/SACH/earnings
# 299
# SGA
# https://api.iextrading.com/1.0/stock/SGA/earnings
# 300
# SNMP
# https://api.iextrading.com/1.0/stock/SNMP/earnings
# 301
# SAND
# https://api.iextrading.com/1.0/stock/SAND/earnings
# 302
# SEB
# https://api.iextrading.com/1.0/stock/SEB/earnings
# 303
# SENS
# https://api.iextrading.com/1.0/stock/SENS/earnings
# 304
# SVT
# https://api.iextrading.com/1.0/stock/SVT/earnings
# 305
# SMTS
# https://api.iextrading.com/1.0/stock/SMTS/earnings
# 306
# SIF
# https://api.iextrading.com/1.0/stock/SIF/earnings
# 307
# SVM
# https://api.iextrading.com/1.0/stock/SVM/earnings
# 308
# SKY
# https://api.iextrading.com/1.0/stock/SKY/earnings
# 309
# XPL
# https://api.iextrading.com/1.0/stock/XPL/earnings
# 310
# SCE^B
# https://api.iextrading.com/1.0/stock/SCE^B/earnings
# 311
# SCE^C
# https://api.iextrading.com/1.0/stock/SCE^C/earnings
# 312
# SCE^D
# https://api.iextrading.com/1.0/stock/SCE^D/earnings
# 313
# SCE^E
# https://api.iextrading.com/1.0/stock/SCE^E/earnings
# 314
# SGB
# https://api.iextrading.com/1.0/stock/SGB/earnings
# 315
# LOV
# https://api.iextrading.com/1.0/stock/LOV/earnings
# 316
# SRCI
# https://api.iextrading.com/1.0/stock/SRCI/earnings
# 317
# SGY.WS
# https://api.iextrading.com/1.0/stock/SGY.WS/earnings
# 318
# STRP
# https://api.iextrading.com/1.0/stock/STRP/earnings
# 319
# SSY
# https://api.iextrading.com/1.0/stock/SSY/earnings
# 320
# SDPI
# https://api.iextrading.com/1.0/stock/SDPI/earnings
# 321
# SYN
# https://api.iextrading.com/1.0/stock/SYN/earnings
# 322
# TKAT
# https://api.iextrading.com/1.0/stock/TKAT/earnings
# 323
# TRX
# https://api.iextrading.com/1.0/stock/TRX/earnings
# 324
# TGB
# https://api.iextrading.com/1.0/stock/TGB/earnings
# 325
# TIK
# https://api.iextrading.com/1.0/stock/TIK/earnings
# 326
# TGC
# https://api.iextrading.com/1.0/stock/TGC/earnings
# 327
# GLU
# https://api.iextrading.com/1.0/stock/GLU/earnings
# 328
# GLU^A
# https://api.iextrading.com/1.0/stock/GLU^A/earnings
# 329
# GGO
# https://api.iextrading.com/1.0/stock/GGO/earnings
# 330
# GGO^A
# https://api.iextrading.com/1.0/stock/GGO^A/earnings
# 331
# TMP
# https://api.iextrading.com/1.0/stock/TMP/earnings
# 332
# TAT
# https://api.iextrading.com/1.0/stock/TAT/earnings
# 333
# TRXC
# https://api.iextrading.com/1.0/stock/TRXC/earnings
# 334
# TMQ
# https://api.iextrading.com/1.0/stock/TMQ/earnings
# 335
# TPHS
# https://api.iextrading.com/1.0/stock/TPHS/earnings
# 336
# TRT
# https://api.iextrading.com/1.0/stock/TRT/earnings
# 337
# HTM
# https://api.iextrading.com/1.0/stock/HTM/earnings
# 338
# UFAB
# https://api.iextrading.com/1.0/stock/UFAB/earnings
# 339
# UAMY
# https://api.iextrading.com/1.0/stock/UAMY/earnings
# 340
# UUU
# https://api.iextrading.com/1.0/stock/UUU/earnings
# 341
# UQM
# https://api.iextrading.com/1.0/stock/UQM/earnings
# 342
# URG
# https://api.iextrading.com/1.0/stock/URG/earnings
# 343
# UEC
# https://api.iextrading.com/1.0/stock/UEC/earnings
# 344
# VII
# https://api.iextrading.com/1.0/stock/VII/earnings
# 345
# VHC
# https://api.iextrading.com/1.0/stock/VHC/earnings
# 346
# VGZ
# https://api.iextrading.com/1.0/stock/VGZ/earnings
# 347
# VNRX
# https://api.iextrading.com/1.0/stock/VNRX/earnings
# 348
# VISI
# https://api.iextrading.com/1.0/stock/VISI/earnings
# 349
# EAD
# https://api.iextrading.com/1.0/stock/EAD/earnings
# 350
# ERC
# https://api.iextrading.com/1.0/stock/ERC/earnings
# 351
# ERH
# https://api.iextrading.com/1.0/stock/ERH/earnings
# 352
# WRN
# https://api.iextrading.com/1.0/stock/WRN/earnings
# 353
# WYY
# https://api.iextrading.com/1.0/stock/WYY/earnings
# 354
# WTT
# https://api.iextrading.com/1.0/stock/WTT/earnings
# 355
# XTNT
# https://api.iextrading.com/1.0/stock/XTNT/earnings
# 356
# YUMA
# https://api.iextrading.com/1.0/stock/YUMA/earnings
# 357
# ZDGE
# https://api.iextrading.com/1.0/stock/ZDGE/earnings
# 358
# ZOM
# https://api.iextrading.com/1.0/stock/ZOM/earnings

# %%
# finding other useful metrics

pe_ratio = []
market_cap = []
ytdchange = []
stocksymbol = []
counter = 0 

for index, row in amex.iterrows():
    counter = counter + 1
    symbol = row["Symbol"]
    url = "https://api.iextrading.com/1.0/stock/"+symbol+"/quote"
    print(counter)
    print(symbol)
    print(url)
    try:
        info = req.get(url).json()
        stocksymbol.append(symbol)
        pe_ratio.append(info["peRatio"])
        market_cap.append(info["marketCap"])
        ytdchange.append(info["ytdChange"])
    except:
        pass
# Out:
# 1
# XXII
# https://api.iextrading.com/1.0/stock/XXII/quote
# 2
# FAX
# https://api.iextrading.com/1.0/stock/FAX/quote
# 3
# IAF
# https://api.iextrading.com/1.0/stock/IAF/quote
# 4
# CH
# https://api.iextrading.com/1.0/stock/CH/quote
# 5
# ABE
# https://api.iextrading.com/1.0/stock/ABE/quote
# 6
# FCO
# https://api.iextrading.com/1.0/stock/FCO/quote
# 7
# IF
# https://api.iextrading.com/1.0/stock/IF/quote
# 8
# ISL
# https://api.iextrading.com/1.0/stock/ISL/quote
# 9
# ACU
# https://api.iextrading.com/1.0/stock/ACU/quote
# 10
# ATNM
# https://api.iextrading.com/1.0/stock/ATNM/quote
# 11
# AE
# https://api.iextrading.com/1.0/stock/AE/quote
# 12
# ACY
# https://api.iextrading.com/1.0/stock/ACY/quote
# 13
# AIRI
# https://api.iextrading.com/1.0/stock/AIRI/quote
# 14
# AXU
# https://api.iextrading.com/1.0/stock/AXU/quote
# 15
# ALO
# https://api.iextrading.com/1.0/stock/ALO/quote
# 16
# AAU
# https://api.iextrading.com/1.0/stock/AAU/quote
# 17
# APT
# https://api.iextrading.com/1.0/stock/APT/quote
# 18
# AAMC
# https://api.iextrading.com/1.0/stock/AAMC/quote
# 19
# DIT
# https://api.iextrading.com/1.0/stock/DIT/quote
# 20
# ALN
# https://api.iextrading.com/1.0/stock/ALN/quote
# 21
# AMS
# https://api.iextrading.com/1.0/stock/AMS/quote
# 22
# USAS
# https://api.iextrading.com/1.0/stock/USAS/quote
# 23
# AMPE
# https://api.iextrading.com/1.0/stock/AMPE/quote
# 24
# APHB
# https://api.iextrading.com/1.0/stock/APHB/quote
# 25
# ARNC^
# https://api.iextrading.com/1.0/stock/ARNC^/quote
# 26
# AKG
# https://api.iextrading.com/1.0/stock/AKG/quote
# 27
# AINC
# https://api.iextrading.com/1.0/stock/AINC/quote
# 28
# ASB.WS
# https://api.iextrading.com/1.0/stock/ASB.WS/quote
# 29
# AST
# https://api.iextrading.com/1.0/stock/AST/quote
# 30
# AUG
# https://api.iextrading.com/1.0/stock/AUG/quote
# 31
# AWX
# https://api.iextrading.com/1.0/stock/AWX/quote
# 32
# ASM
# https://api.iextrading.com/1.0/stock/ASM/quote
# 33
# BTG
# https://api.iextrading.com/1.0/stock/BTG/quote
# 34
# BTN
# https://api.iextrading.com/1.0/stock/BTN/quote
# 35
# BKJ
# https://api.iextrading.com/1.0/stock/BKJ/quote
# 36
# BCV
# https://api.iextrading.com/1.0/stock/BCV/quote
# 37
# BCV^A
# https://api.iextrading.com/1.0/stock/BCV^A/quote
# 38
# BAA
# https://api.iextrading.com/1.0/stock/BAA/quote
# 39
# BHB
# https://api.iextrading.com/1.0/stock/BHB/quote
# 40
# BRN
# https://api.iextrading.com/1.0/stock/BRN/quote
# 41
# BGSF
# https://api.iextrading.com/1.0/stock/BGSF/quote
# 42
# BPMX
# https://api.iextrading.com/1.0/stock/BPMX/quote
# 43
# BTX
# https://api.iextrading.com/1.0/stock/BTX/quote
# 44
# BTX.WS
# https://api.iextrading.com/1.0/stock/BTX.WS/quote
# 45
# BGI
# https://api.iextrading.com/1.0/stock/BGI/quote
# 46
# BZM
# https://api.iextrading.com/1.0/stock/BZM/quote
# 47
# MHE
# https://api.iextrading.com/1.0/stock/MHE/quote
# 48
# BLE
# https://api.iextrading.com/1.0/stock/BLE/quote
# 49
# BLJ
# https://api.iextrading.com/1.0/stock/BLJ/quote
# 50
# BFY
# https://api.iextrading.com/1.0/stock/BFY/quote
# 51
# BHV
# https://api.iextrading.com/1.0/stock/BHV/quote
# 52
# BDR
# https://api.iextrading.com/1.0/stock/BDR/quote
# 53
# BRG
# https://api.iextrading.com/1.0/stock/BRG/quote
# 54
# BRG^A
# https://api.iextrading.com/1.0/stock/BRG^A/quote
# 55
# BRG^C
# https://api.iextrading.com/1.0/stock/BRG^C/quote
# 56
# BRG^D
# https://api.iextrading.com/1.0/stock/BRG^D/quote
# 57
# BVX
# https://api.iextrading.com/1.0/stock/BVX/quote
# 58
# BWL.A
# https://api.iextrading.com/1.0/stock/BWL.A/quote
# 59
# CMCL
# https://api.iextrading.com/1.0/stock/CMCL/quote
# 60
# CEI
# https://api.iextrading.com/1.0/stock/CEI/quote
# 61
# CANF
# https://api.iextrading.com/1.0/stock/CANF/quote
# 62
# ROX
# https://api.iextrading.com/1.0/stock/ROX/quote
# 63
# CAW
# https://api.iextrading.com/1.0/stock/CAW/quote
# 64
# CVM
# https://api.iextrading.com/1.0/stock/CVM/quote
# 65
# CVM.WS
# https://api.iextrading.com/1.0/stock/CVM.WS/quote
# 66
# CEF
# https://api.iextrading.com/1.0/stock/CEF/quote
# 67
# CET
# https://api.iextrading.com/1.0/stock/CET/quote
# 68
# LEU
# https://api.iextrading.com/1.0/stock/LEU/quote
# 69
# CCF
# https://api.iextrading.com/1.0/stock/CCF/quote
# 70
# CQH
# https://api.iextrading.com/1.0/stock/CQH/quote
# 71
# CQP
# https://api.iextrading.com/1.0/stock/CQP/quote
# 72
# LNG
# https://api.iextrading.com/1.0/stock/LNG/quote
# 73
# CVR
# https://api.iextrading.com/1.0/stock/CVR/quote
# 74
# CPHI
# https://api.iextrading.com/1.0/stock/CPHI/quote
# 75
# CISN.WS
# https://api.iextrading.com/1.0/stock/CISN.WS/quote
# 76
# CKX
# https://api.iextrading.com/1.0/stock/CKX/quote
# 77
# GLV
# https://api.iextrading.com/1.0/stock/GLV/quote
# 78
# GLQ
# https://api.iextrading.com/1.0/stock/GLQ/quote
# 79
# GLO
# https://api.iextrading.com/1.0/stock/GLO/quote
# 80
# COHN
# https://api.iextrading.com/1.0/stock/COHN/quote
# 81
# MOC
# https://api.iextrading.com/1.0/stock/MOC/quote
# 82
# CIX
# https://api.iextrading.com/1.0/stock/CIX/quote
# 83
# LODE
# https://api.iextrading.com/1.0/stock/LODE/quote
# 84
# CDOR
# https://api.iextrading.com/1.0/stock/CDOR/quote
# 85
# CTO
# https://api.iextrading.com/1.0/stock/CTO/quote
# 86
# MCF
# https://api.iextrading.com/1.0/stock/MCF/quote
# 87
# CUO
# https://api.iextrading.com/1.0/stock/CUO/quote
# 88
# CMT
# https://api.iextrading.com/1.0/stock/CMT/quote
# 89
# CVRS
# https://api.iextrading.com/1.0/stock/CVRS/quote
# 90
# CRMD
# https://api.iextrading.com/1.0/stock/CRMD/quote
# 91
# CRF
# https://api.iextrading.com/1.0/stock/CRF/quote
# 92
# CLM
# https://api.iextrading.com/1.0/stock/CLM/quote
# 93
# CVU
# https://api.iextrading.com/1.0/stock/CVU/quote
# 94
# CIK
# https://api.iextrading.com/1.0/stock/CIK/quote
# 95
# DHY
# https://api.iextrading.com/1.0/stock/DHY/quote
# 96
# CRHM
# https://api.iextrading.com/1.0/stock/CRHM/quote
# 97
# CRVP
# https://api.iextrading.com/1.0/stock/CRVP/quote
# 98
# CTEK
# https://api.iextrading.com/1.0/stock/CTEK/quote
# 99
# DXR
# https://api.iextrading.com/1.0/stock/DXR/quote
# 100
# VCF
# https://api.iextrading.com/1.0/stock/VCF/quote
# 101
# VFL
# https://api.iextrading.com/1.0/stock/VFL/quote
# 102
# VMM
# https://api.iextrading.com/1.0/stock/VMM/quote
# 103
# DLA
# https://api.iextrading.com/1.0/stock/DLA/quote
# 104
# DNN
# https://api.iextrading.com/1.0/stock/DNN/quote
# 105
# DGSE
# https://api.iextrading.com/1.0/stock/DGSE/quote
# 106
# DPW
# https://api.iextrading.com/1.0/stock/DPW/quote
# 107
# DSS
# https://api.iextrading.com/1.0/stock/DSS/quote
# 108
# DMF
# https://api.iextrading.com/1.0/stock/DMF/quote
# 109
# GRF
# https://api.iextrading.com/1.0/stock/GRF/quote
# 110
# EVM
# https://api.iextrading.com/1.0/stock/EVM/quote
# 111
# EIA
# https://api.iextrading.com/1.0/stock/EIA/quote
# 112
# CEV
# https://api.iextrading.com/1.0/stock/CEV/quote
# 113
# EVV
# https://api.iextrading.com/1.0/stock/EVV/quote
# 114
# MAB
# https://api.iextrading.com/1.0/stock/MAB/quote
# 115
# MMV
# https://api.iextrading.com/1.0/stock/MMV/quote
# 116
# MIW
# https://api.iextrading.com/1.0/stock/MIW/quote
# 117
# EMI
# https://api.iextrading.com/1.0/stock/EMI/quote
# 118
# EIM
# https://api.iextrading.com/1.0/stock/EIM/quote
# 119
# EIV
# https://api.iextrading.com/1.0/stock/EIV/quote
# 120
# EMJ
# https://api.iextrading.com/1.0/stock/EMJ/quote
# 121
# EVJ
# https://api.iextrading.com/1.0/stock/EVJ/quote
# 122
# ENX
# https://api.iextrading.com/1.0/stock/ENX/quote
# 123
# NYH
# https://api.iextrading.com/1.0/stock/NYH/quote
# 124
# EVY
# https://api.iextrading.com/1.0/stock/EVY/quote
# 125
# EIO
# https://api.iextrading.com/1.0/stock/EIO/quote
# 126
# EVO
# https://api.iextrading.com/1.0/stock/EVO/quote
# 127
# EIP
# https://api.iextrading.com/1.0/stock/EIP/quote
# 128
# EVP
# https://api.iextrading.com/1.0/stock/EVP/quote
# 129
# ELMD
# https://api.iextrading.com/1.0/stock/ELMD/quote
# 130
# ELLO
# https://api.iextrading.com/1.0/stock/ELLO/quote
# 131
# ECF
# https://api.iextrading.com/1.0/stock/ECF/quote
# 132
# ECF^A
# https://api.iextrading.com/1.0/stock/ECF^A/quote
# 133
# EMAN
# https://api.iextrading.com/1.0/stock/EMAN/quote
# 134
# MSN
# https://api.iextrading.com/1.0/stock/MSN/quote
# 135
# EMX
# https://api.iextrading.com/1.0/stock/EMX/quote
# 136
# UUUU
# https://api.iextrading.com/1.0/stock/UUUU/quote
# 137
# UUUU.WS
# https://api.iextrading.com/1.0/stock/UUUU.WS/quote
# 138
# ENRJ
# https://api.iextrading.com/1.0/stock/ENRJ/quote
# 139
# ENSV
# https://api.iextrading.com/1.0/stock/ENSV/quote
# 140
# ESNC
# https://api.iextrading.com/1.0/stock/ESNC/quote
# 141
# EGI
# https://api.iextrading.com/1.0/stock/EGI/quote
# 142
# EVI
# https://api.iextrading.com/1.0/stock/EVI/quote
# 143
# ERN
# https://api.iextrading.com/1.0/stock/ERN/quote
# 144
# ESP
# https://api.iextrading.com/1.0/stock/ESP/quote
# 145
# EVBN
# https://api.iextrading.com/1.0/stock/EVBN/quote
# 146
# EPM
# https://api.iextrading.com/1.0/stock/EPM/quote
# 147
# FEN
# https://api.iextrading.com/1.0/stock/FEN/quote
# 148
# BDL
# https://api.iextrading.com/1.0/stock/BDL/quote
# 149
# FSI
# https://api.iextrading.com/1.0/stock/FSI/quote
# 150
# FTF
# https://api.iextrading.com/1.0/stock/FTF/quote
# 151
# FSP
# https://api.iextrading.com/1.0/stock/FSP/quote
# 152
# FRD
# https://api.iextrading.com/1.0/stock/FRD/quote
# 153
# FTNW
# https://api.iextrading.com/1.0/stock/FTNW/quote
# 154
# GGN
# https://api.iextrading.com/1.0/stock/GGN/quote
# 155
# GGN^B
# https://api.iextrading.com/1.0/stock/GGN^B/quote
# 156
# GST
# https://api.iextrading.com/1.0/stock/GST/quote
# 157
# GST^A
# https://api.iextrading.com/1.0/stock/GST^A/quote
# 158
# GST^B
# https://api.iextrading.com/1.0/stock/GST^B/quote
# 159
# JOB
# https://api.iextrading.com/1.0/stock/JOB/quote
# 160
# GMO
# https://api.iextrading.com/1.0/stock/GMO/quote
# 161
# GSB
# https://api.iextrading.com/1.0/stock/GSB/quote
# 162
# GSAT
# https://api.iextrading.com/1.0/stock/GSAT/quote
# 163
# GLOW
# https://api.iextrading.com/1.0/stock/GLOW/quote
# 164
# GORO
# https://api.iextrading.com/1.0/stock/GORO/quote
# 165
# GSV
# https://api.iextrading.com/1.0/stock/GSV/quote
# 166
# AUMN
# https://api.iextrading.com/1.0/stock/AUMN/quote
# 167
# GSS
# https://api.iextrading.com/1.0/stock/GSS/quote
# 168
# GV
# https://api.iextrading.com/1.0/stock/GV/quote
# 169
# GDP
# https://api.iextrading.com/1.0/stock/GDP/quote
# 170
# GTE
# https://api.iextrading.com/1.0/stock/GTE/quote
# 171
# GPL
# https://api.iextrading.com/1.0/stock/GPL/quote
# 172
# SIM
# https://api.iextrading.com/1.0/stock/SIM/quote
# 173
# GVP
# https://api.iextrading.com/1.0/stock/GVP/quote
# 174
# GLF
# https://api.iextrading.com/1.0/stock/GLF/quote
# 175
# GLF.WS
# https://api.iextrading.com/1.0/stock/GLF.WS/quote
# 176
# HEB
# https://api.iextrading.com/1.0/stock/HEB/quote
# 177
# HCAC
# https://api.iextrading.com/1.0/stock/HCAC/quote
# 178
# HCAC.U
# https://api.iextrading.com/1.0/stock/HCAC.U/quote
# 179
# HCAC.WS
# https://api.iextrading.com/1.0/stock/HCAC.WS/quote
# 180
# HLM^
# https://api.iextrading.com/1.0/stock/HLM^/quote
# 181
# HMG
# https://api.iextrading.com/1.0/stock/HMG/quote
# 182
# HUSA
# https://api.iextrading.com/1.0/stock/HUSA/quote
# 183
# IBIO
# https://api.iextrading.com/1.0/stock/IBIO/quote
# 184
# IBO
# https://api.iextrading.com/1.0/stock/IBO/quote
# 185
# IEC
# https://api.iextrading.com/1.0/stock/IEC/quote
# 186
# IMUC
# https://api.iextrading.com/1.0/stock/IMUC/quote
# 187
# IMUC.WS
# https://api.iextrading.com/1.0/stock/IMUC.WS/quote
# 188
# IMH
# https://api.iextrading.com/1.0/stock/IMH/quote
# 189
# IMO
# https://api.iextrading.com/1.0/stock/IMO/quote
# 190
# IOR
# https://api.iextrading.com/1.0/stock/IOR/quote
# 191
# IGC
# https://api.iextrading.com/1.0/stock/IGC/quote
# 192
# INFU
# https://api.iextrading.com/1.0/stock/INFU/quote
# 193
# IHT
# https://api.iextrading.com/1.0/stock/IHT/quote
# 194
# NSPR
# https://api.iextrading.com/1.0/stock/NSPR/quote
# 195
# NSPR.WS
# https://api.iextrading.com/1.0/stock/NSPR.WS/quote
# 196
# NSPR.WS.B
# https://api.iextrading.com/1.0/stock/NSPR.WS.B/quote
# 197
# IDN
# https://api.iextrading.com/1.0/stock/IDN/quote
# 198
# INS
# https://api.iextrading.com/1.0/stock/INS/quote
# 199
# THM
# https://api.iextrading.com/1.0/stock/THM/quote
# 200
# INTT
# https://api.iextrading.com/1.0/stock/INTT/quote
# 201
# INUV
# https://api.iextrading.com/1.0/stock/INUV/quote
# 202
# VKI
# https://api.iextrading.com/1.0/stock/VKI/quote
# 203
# ISR
# https://api.iextrading.com/1.0/stock/ISR/quote
# 204
# ISDR
# https://api.iextrading.com/1.0/stock/ISDR/quote
# 205
# JRJR
# https://api.iextrading.com/1.0/stock/JRJR/quote
# 206
# KIQ
# https://api.iextrading.com/1.0/stock/KIQ/quote
# 207
# KLDX
# https://api.iextrading.com/1.0/stock/KLDX/quote
# 208
# LTS
# https://api.iextrading.com/1.0/stock/LTS/quote
# 209
# LTS^A
# https://api.iextrading.com/1.0/stock/LTS^A/quote
# 210
# LTSL
# https://api.iextrading.com/1.0/stock/LTSL/quote
# 211
# LAQ
# https://api.iextrading.com/1.0/stock/LAQ/quote
# 212
# LEVB
# https://api.iextrading.com/1.0/stock/LEVB/quote
# 213
# LGL
# https://api.iextrading.com/1.0/stock/LGL/quote
# 214
# LBY
# https://api.iextrading.com/1.0/stock/LBY/quote
# 215
# LLEX
# https://api.iextrading.com/1.0/stock/LLEX/quote
# 216
# LIQT
# https://api.iextrading.com/1.0/stock/LIQT/quote
# 217
# MAG
# https://api.iextrading.com/1.0/stock/MAG/quote
# 218
# MJCO
# https://api.iextrading.com/1.0/stock/MJCO/quote
# 219
# MHH
# https://api.iextrading.com/1.0/stock/MHH/quote
# 220
# MTNB
# https://api.iextrading.com/1.0/stock/MTNB/quote
# 221
# MNI
# https://api.iextrading.com/1.0/stock/MNI/quote
# 222
# IPB
# https://api.iextrading.com/1.0/stock/IPB/quote
# 223
# MXC
# https://api.iextrading.com/1.0/stock/MXC/quote
# 224
# CCA
# https://api.iextrading.com/1.0/stock/CCA/quote
# 225
# MICR
# https://api.iextrading.com/1.0/stock/MICR/quote
# 226
# MLSS
# https://api.iextrading.com/1.0/stock/MLSS/quote
# 227
# MVF
# https://api.iextrading.com/1.0/stock/MVF/quote
# 228
# MZA
# https://api.iextrading.com/1.0/stock/MZA/quote
# 229
# MYO
# https://api.iextrading.com/1.0/stock/MYO/quote
# 230
# NNVC
# https://api.iextrading.com/1.0/stock/NNVC/quote
# 231
# ATEST
# https://api.iextrading.com/1.0/stock/ATEST/quote
# 232
# ATEST.A
# https://api.iextrading.com/1.0/stock/ATEST.A/quote
# 233
# ATEST.B
# https://api.iextrading.com/1.0/stock/ATEST.B/quote
# 234
# ATEST.C
# https://api.iextrading.com/1.0/stock/ATEST.C/quote
# 235
# NHC
# https://api.iextrading.com/1.0/stock/NHC/quote
# 236
# NAVB
# https://api.iextrading.com/1.0/stock/NAVB/quote
# 237
# NTIP
# https://api.iextrading.com/1.0/stock/NTIP/quote
# 238
# NBW
# https://api.iextrading.com/1.0/stock/NBW/quote
# 239
# NHS
# https://api.iextrading.com/1.0/stock/NHS/quote
# 240
# NBH
# https://api.iextrading.com/1.0/stock/NBH/quote
# 241
# NML
# https://api.iextrading.com/1.0/stock/NML/quote
# 242
# NBO
# https://api.iextrading.com/1.0/stock/NBO/quote
# 243
# NRO
# https://api.iextrading.com/1.0/stock/NRO/quote
# 244
# UWN
# https://api.iextrading.com/1.0/stock/UWN/quote
# 245
# NSU
# https://api.iextrading.com/1.0/stock/NSU/quote
# 246
# GBR
# https://api.iextrading.com/1.0/stock/GBR/quote
# 247
# NEN
# https://api.iextrading.com/1.0/stock/NEN/quote
# 248
# NGD
# https://api.iextrading.com/1.0/stock/NGD/quote
# 249
# NXE
# https://api.iextrading.com/1.0/stock/NXE/quote
# 250
# HLTH
# https://api.iextrading.com/1.0/stock/HLTH/quote
# 251
# NAK
# https://api.iextrading.com/1.0/stock/NAK/quote
# 252
# NOG
# https://api.iextrading.com/1.0/stock/NOG/quote
# 253
# NBY
# https://api.iextrading.com/1.0/stock/NBY/quote
# 254
# NG
# https://api.iextrading.com/1.0/stock/NG/quote
# 255
# NTN
# https://api.iextrading.com/1.0/stock/NTN/quote
# 256
# NES
# https://api.iextrading.com/1.0/stock/NES/quote
# 257
# OCX
# https://api.iextrading.com/1.0/stock/OCX/quote
# 258
# OGEN
# https://api.iextrading.com/1.0/stock/OGEN/quote
# 259
# TIS
# https://api.iextrading.com/1.0/stock/TIS/quote
# 260
# ONP
# https://api.iextrading.com/1.0/stock/ONP/quote
# 261
# ORM
# https://api.iextrading.com/1.0/stock/ORM/quote
# 262
# PCG^A
# https://api.iextrading.com/1.0/stock/PCG^A/quote
# 263
# PCG^B
# https://api.iextrading.com/1.0/stock/PCG^B/quote
# 264
# PCG^C
# https://api.iextrading.com/1.0/stock/PCG^C/quote
# 265
# PCG^D
# https://api.iextrading.com/1.0/stock/PCG^D/quote
# 266
# PCG^E
# https://api.iextrading.com/1.0/stock/PCG^E/quote
# 267
# PCG^G
# https://api.iextrading.com/1.0/stock/PCG^G/quote
# 268
# PCG^H
# https://api.iextrading.com/1.0/stock/PCG^H/quote
# 269
# PCG^I
# https://api.iextrading.com/1.0/stock/PCG^I/quote
# 270
# PTN
# https://api.iextrading.com/1.0/stock/PTN/quote
# 271
# PARR
# https://api.iextrading.com/1.0/stock/PARR/quote
# 272
# PZG
# https://api.iextrading.com/1.0/stock/PZG/quote
# 273
# TEUM
# https://api.iextrading.com/1.0/stock/TEUM/quote
# 274
# PRK
# https://api.iextrading.com/1.0/stock/PRK/quote
# 275
# BTU^
# https://api.iextrading.com/1.0/stock/BTU^/quote
# 276
# PED
# https://api.iextrading.com/1.0/stock/PED/quote
# 277
# PFNX
# https://api.iextrading.com/1.0/stock/PFNX/quote
# 278
# HNW
# https://api.iextrading.com/1.0/stock/HNW/quote
# 279
# PLG
# https://api.iextrading.com/1.0/stock/PLG/quote
# 280
# PLYM
# https://api.iextrading.com/1.0/stock/PLYM/quote
# 281
# PLYM^A
# https://api.iextrading.com/1.0/stock/PLYM^A/quote
# 282
# PLM
# https://api.iextrading.com/1.0/stock/PLM/quote
# 283
# PW
# https://api.iextrading.com/1.0/stock/PW/quote
# 284
# PW^A
# https://api.iextrading.com/1.0/stock/PW^A/quote
# 285
# PLX
# https://api.iextrading.com/1.0/stock/PLX/quote
# 286
# RLGT
# https://api.iextrading.com/1.0/stock/RLGT/quote
# 287
# RLGT^A
# https://api.iextrading.com/1.0/stock/RLGT^A/quote
# 288
# UTG
# https://api.iextrading.com/1.0/stock/UTG/quote
# 289
# REED
# https://api.iextrading.com/1.0/stock/REED/quote
# 290
# RHE
# https://api.iextrading.com/1.0/stock/RHE/quote
# 291
# RHE^A
# https://api.iextrading.com/1.0/stock/RHE^A/quote
# 292
# RWC
# https://api.iextrading.com/1.0/stock/RWC/quote
# 293
# RCG
# https://api.iextrading.com/1.0/stock/RCG/quote
# 294
# RVP
# https://api.iextrading.com/1.0/stock/RVP/quote
# 295
# RNN
# https://api.iextrading.com/1.0/stock/RNN/quote
# 296
# REI
# https://api.iextrading.com/1.0/stock/REI/quote
# 297
# RIF
# https://api.iextrading.com/1.0/stock/RIF/quote
# 298
# SACH
# https://api.iextrading.com/1.0/stock/SACH/quote
# 299
# SGA
# https://api.iextrading.com/1.0/stock/SGA/quote
# 300
# SNMP
# https://api.iextrading.com/1.0/stock/SNMP/quote
# 301
# SAND
# https://api.iextrading.com/1.0/stock/SAND/quote
# 302
# SEB
# https://api.iextrading.com/1.0/stock/SEB/quote
# 303
# SENS
# https://api.iextrading.com/1.0/stock/SENS/quote
# 304
# SVT
# https://api.iextrading.com/1.0/stock/SVT/quote
# 305
# SMTS
# https://api.iextrading.com/1.0/stock/SMTS/quote
# 306
# SIF
# https://api.iextrading.com/1.0/stock/SIF/quote
# 307
# SVM
# https://api.iextrading.com/1.0/stock/SVM/quote
# 308
# SKY
# https://api.iextrading.com/1.0/stock/SKY/quote
# 309
# XPL
# https://api.iextrading.com/1.0/stock/XPL/quote
# 310
# SCE^B
# https://api.iextrading.com/1.0/stock/SCE^B/quote
# 311
# SCE^C
# https://api.iextrading.com/1.0/stock/SCE^C/quote
# 312
# SCE^D
# https://api.iextrading.com/1.0/stock/SCE^D/quote
# 313
# SCE^E
# https://api.iextrading.com/1.0/stock/SCE^E/quote
# 314
# SGB
# https://api.iextrading.com/1.0/stock/SGB/quote
# 315
# LOV
# https://api.iextrading.com/1.0/stock/LOV/quote
# 316
# SRCI
# https://api.iextrading.com/1.0/stock/SRCI/quote
# 317
# SGY.WS
# https://api.iextrading.com/1.0/stock/SGY.WS/quote
# 318
# STRP
# https://api.iextrading.com/1.0/stock/STRP/quote
# 319
# SSY
# https://api.iextrading.com/1.0/stock/SSY/quote
# 320
# SDPI
# https://api.iextrading.com/1.0/stock/SDPI/quote
# 321
# SYN
# https://api.iextrading.com/1.0/stock/SYN/quote
# 322
# TKAT
# https://api.iextrading.com/1.0/stock/TKAT/quote
# 323
# TRX
# https://api.iextrading.com/1.0/stock/TRX/quote
# 324
# TGB
# https://api.iextrading.com/1.0/stock/TGB/quote
# 325
# TIK
# https://api.iextrading.com/1.0/stock/TIK/quote
# 326
# TGC
# https://api.iextrading.com/1.0/stock/TGC/quote
# 327
# GLU
# https://api.iextrading.com/1.0/stock/GLU/quote
# 328
# GLU^A
# https://api.iextrading.com/1.0/stock/GLU^A/quote
# 329
# GGO
# https://api.iextrading.com/1.0/stock/GGO/quote
# 330
# GGO^A
# https://api.iextrading.com/1.0/stock/GGO^A/quote
# 331
# TMP
# https://api.iextrading.com/1.0/stock/TMP/quote
# 332
# TAT
# https://api.iextrading.com/1.0/stock/TAT/quote
# 333
# TRXC
# https://api.iextrading.com/1.0/stock/TRXC/quote
# 334
# TMQ
# https://api.iextrading.com/1.0/stock/TMQ/quote
# 335
# TPHS
# https://api.iextrading.com/1.0/stock/TPHS/quote
# 336
# TRT
# https://api.iextrading.com/1.0/stock/TRT/quote
# 337
# HTM
# https://api.iextrading.com/1.0/stock/HTM/quote
# 338
# UFAB
# https://api.iextrading.com/1.0/stock/UFAB/quote
# 339
# UAMY
# https://api.iextrading.com/1.0/stock/UAMY/quote
# 340
# UUU
# https://api.iextrading.com/1.0/stock/UUU/quote
# 341
# UQM
# https://api.iextrading.com/1.0/stock/UQM/quote
# 342
# URG
# https://api.iextrading.com/1.0/stock/URG/quote
# 343
# UEC
# https://api.iextrading.com/1.0/stock/UEC/quote
# 344
# VII
# https://api.iextrading.com/1.0/stock/VII/quote
# 345
# VHC
# https://api.iextrading.com/1.0/stock/VHC/quote
# 346
# VGZ
# https://api.iextrading.com/1.0/stock/VGZ/quote
# 347
# VNRX
# https://api.iextrading.com/1.0/stock/VNRX/quote
# 348
# VISI
# https://api.iextrading.com/1.0/stock/VISI/quote
# 349
# EAD
# https://api.iextrading.com/1.0/stock/EAD/quote
# 350
# ERC
# https://api.iextrading.com/1.0/stock/ERC/quote
# 351
# ERH
# https://api.iextrading.com/1.0/stock/ERH/quote
# 352
# WRN
# https://api.iextrading.com/1.0/stock/WRN/quote
# 353
# WYY
# https://api.iextrading.com/1.0/stock/WYY/quote
# 354
# WTT
# https://api.iextrading.com/1.0/stock/WTT/quote
# 355
# XTNT
# https://api.iextrading.com/1.0/stock/XTNT/quote
# 356
# YUMA
# https://api.iextrading.com/1.0/stock/YUMA/quote
# 357
# ZDGE
# https://api.iextrading.com/1.0/stock/ZDGE/quote
# 358
# ZOM
# https://api.iextrading.com/1.0/stock/ZOM/quote

# %%
metrics = pd.DataFrame({
    "Ticker": stocksymbol,s
    "PE Ratio":pe_ratio,
    "Market Cap":market_cap,
    "Year To Date Change": ytdchange
})
metrics
# Out:
#      Market Cap  PE Ratio  Year To Date Change
# 0     412704151       NaN             0.040498
# 1    1258132812       NaN             0.022541
# 2     149735474       NaN             0.035220
# 3      87307248       NaN             0.021906
# 4     144264006       NaN             0.031186
# 5      79308332       NaN             0.025959
# 6      73963217       NaN             0.036963
# 7      82657555       NaN             0.020458
# 8      81753498     17.31             0.054395
# 9      59218554       NaN             0.146398
# 10    199492291       NaN             0.075000
# 11     21421197     10.22            -0.008843
# 12     37718186       NaN            -0.079545
# 13    163002904       NaN            -0.035928
# 14    162630519       NaN            -0.026738
# 15    104128757       NaN            -0.019417
# 16     57590987       NaN            -0.012987
# 17    127579491       NaN             0.026171
# 18     59603699       NaN            -0.030337
# 19      8037613       NaN             0.136979
# 20     15417000       NaN             0.058824
# 21    170137495       NaN             0.007371
# 22    222509500       NaN            -0.158046
# 23     10638799       NaN             0.108911
# 24    168090354       NaN             0.149096
# 25    198808495     63.76             0.001687
# 26    132670298       NaN             0.139535
# 27    114611796       NaN            -0.093168
# 28      7910928       NaN             0.014634
# 29     80131593     38.00             0.048276
# ..          ...       ...                  ...
# 281    86787013       NaN            -0.002863
# 282    29628269       NaN             0.019956
# 283  1263542108     19.46             0.024279
# 284    62898945       NaN            -0.137931
# 285   396490629     -4.42            -0.038647
# 286   158526785    -10.71             0.271186
# 287   222364198       NaN             0.010000
# 288    20279736       NaN            -0.111455
# 289    75564107     56.00             0.149560
# 290    78548382     11.84             0.040052
# 291    22608531       NaN             0.080645
# 292     3816264       NaN            -0.057143
# 293    77297902     -9.53             0.059259
# 294   108808779     37.25             0.027586
# 295   268578977    -12.29            -0.094737
# 296     7547628       NaN             0.023810
# 297   241227899       NaN             0.078947
# 298    78088131     -6.55             0.076027
# 299    73721986       NaN            -0.010676
# 300    92443784     -7.46             0.142857
# 301   600118852       NaN             0.004723
# 302   460854432       NaN             0.027259
# 303   120682470       NaN            -0.002674
# 304    97620474       NaN            -0.028846
# 305    55631170       NaN            -0.014706
# 306    57318528       NaN             0.026531
# 307    10175067     -0.49            -0.017719
# 308    36938666       NaN             0.405172
# 309    27008800    -45.17             0.003704
# 310   180451738       NaN             0.052632
#
# [311 rows x 3 columns]

# %%
new_amex = pd.DataFrame({
    "Ticker":ticker,
    "Date":date,
    "Open":monthly_open,
    "Close": monthly_close
})
new_amex.dropna(how='any',inplace=True)
new_amex.to_csv("AMEX_daytoday.csv")

# %%
actual_eps
# Out:
# [None,
#  -0.03,
#  -0.04,
#  -0.03,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  0.32,
#  0.75,
#  0.18,
#  None,
#  None,
#  -0.12,
#  -0.14,
#  None,
#  None,
#  None,
#  None,
#  None,
#  0.27,
#  0.25,
#  0.41,
#  None,
#  -0.2,
#  -0.36,
#  -0.15,
#  None,
#  None,
#  None,
#  None,
#  None,
#  0.12,
#  0.1,
#  0.2,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  -0.07,
#  0.02,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  -0.09,
#  -0.78,
#  -1.94,
#  None,
#  0.02,
#  None,
#  0.04,
#  None,
#  0.73,
#  0.76,
#  None,
#  None,
#  -0.15,
#  -0.18,
#  -0.17,
#  None,
#  0.02,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  -0.01,
#  0.02,
#  0.01,
#  None,
#  0.01,
#  None,
#  0.02,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  0.35,
#  0.25,
#  0.15,
#  -0.09,
#  -0.13,
#  -0.18,
#  -0.17,
#  None,
#  -0.05,
#  -0.05,
#  -0.08,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  0.13,
#  0.13,
#  0.18,
#  None,
#  -0.04,
#  -0.04,
#  -0.06,
#  None,
#  None,
#  None,
#  None,
#  None,
#  0.41,
#  0.19,
#  None,
#  None,
#  None,
#  None,
#  -0.8,
#  None,
#  -0.04,
#  -0.12,
#  -0.08,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  -0.58,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  0.02,
#  0.02,
#  0.02,
#  None,
#  -1.1,
#  -3.71,
#  0.8,
#  None,
#  -1.09,
#  -1.23,
#  0.23,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  0.02,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  -0.01,
#  None,
#  0.28,
#  0.24,
#  None,
#  None,
#  0.18,
#  0.67,
#  2.27,
#  None,
#  -0.28,
#  -0.24,
#  0.04,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  -0.04,
#  -0.07,
#  None,
#  None,
#  -0.14,
#  -0.19,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  0.19,
#  0.09,
#  0.14,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  0.03,
#  0.04,
#  0.02,
#  None,
#  None,
#  None,
#  None,
#  None,
#  0.24,
#  0.08,
#  0.11,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  0.27,
#  0.57,
#  0.47,
#  -0.08,
#  None,
#  -0.01,
#  -0.01,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  -0.15,
#  -0.2,
#  -0.1,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  0.11,
#  0.08,
#  0.05,
#  0.02,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  -0.09,
#  -0.07,
#  -0.06,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  -0.02,
#  None,
#  -0.07,
#  -0.03,
#  -0.15,
#  None,
#  None,
#  None,
#  None,
#  None,
#  -0.05,
#  -0.04,
#  None,
#  -0.09,
#  -0.09,
#  -0.09,
#  -0.1,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  0.05,
#  0.07,
#  0.07,
#  0.06,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  0.05,
#  0.14,
#  None,
#  None,
#  None,
#  None,
#  None,
#  0.26,
#  0.27,
#  0.27,
#  None,
#  None,
#  None,
#  -0.21,
#  None,
#  1.3,
#  -1,
#  -1.25,
#  None,
#  None,
#  None,
#  None,
#  None,
#  -0.05,
#  -0.05,
#  -0.06,
#  -0.15,
#  None,
#  -0.01,
#  0.01,
#  None,
#  -0.02,
#  -0.02,
#  -0.02,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  -0.02,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  -0.02,
#  -0.01,
#  -0.01,
#  None,
#  None,
#  None,
#  -0.01,
#  None,
#  0.05,
#  0.02,
#  0.01,
#  None,
#  None,
#  None,
#  None,
#  None,
#  0.05,
#  -0.13,
#  -0.63,
#  None,
#  0.01,
#  -0.02,
#  0.03,
#  None,
#  None,
#  None,
#  0.02,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  0.07,
#  0.08,
#  -0.06,
#  -0.09,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  0.35,
#  -0.07,
#  0.3,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  -0.02,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  -0.05,
#  -0.04,
#  -0.21,
#  None,
#  None,
#  None,
#  None,
#  -0.08,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  0.2,
#  0.16,
#  0.2,
#  None,
#  -0.03,
#  -0.05,
#  -0.06,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  -0.04,
#  0.04,
#  -0.06,
#  None,
#  -0.02,
#  -0.03,
#  -0.06,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  0.04,
#  0.36,
#  -0.3,
#  None,
#  -0.12,
#  -0.57,
#  -0.32,
#  None,
#  -0.03,
#  -0.03,
#  -0.03,
#  None,
#  -0.01,
#  -0.02,
#  None,
#  -0.02,
#  0.01,
#  0.01,
#  -0.02,
#  None,
#  None,
#  None,
#  None,
#  None,
#  -0.04,
#  -0.04,
#  None,
#  None,
#  -0.78,
#  -0.79,
#  -1.91,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  -0.14,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  -0.21,
#  -1.06,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  -0.15,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  0.01,
#  0.02,
#  0.02,
#  None,
#  None,
#  None,
#  None,
#  None,
#  0.01,
#  0.02,
#  -0.02,
#  None,
#  -0.05,
#  None,
#  None,
#  None,
#  0.04,
#  None,
#  None,
#  None,
#  -0.16,
#  -0.11,
#  -0.26,
#  None,
#  -0.03,
#  -0.03,
#  None,
#  None,
#  -0.07,
#  -0.07,
#  -0.04,
#  None,
#  None,
#  None,
#  None,
#  None,
#  -0.12,
#  -0.13,
#  -0.16,
#  None,
#  None,
#  -0.02,
#  -0.04,
#  None,
#  0.07,
#  -0.12,
#  -0.08,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  0.07,
#  -0.02,
#  -0.06,
#  -0.08,
#  None,
#  0.55,
#  0.24,
#  0.43,
#  None,
#  None,
#  -0.12,
#  None,
#  None,
#  -0.16,
#  -0.1,
#  -0.14,
#  None,
#  1.44,
#  1.24,
#  1.31,
#  None,
#  None,
#  None,
#  None,
#  None,
#  -0.37,
#  -0.52,
#  -0.43,
#  None,
#  None,
#  None,
#  None,
#  0.4,
#  None,
#  None,
#  None,
#  None,
#  0.18,
#  -0.63,
#  None,
#  -0.01,
#  -0.01,
#  -0.01,
#  -0.01,
#  None,
#  None,
#  None,
#  None,
#  None,
#  -0.09,
#  -0.06,
#  -0.07,
#  0.07,
#  0.07,
#  0.1,
#  0.03,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  0.25,
#  -0.14,
#  ...]

# %%
newearnings = pd.DataFrame({
    "Ticker": stock_ticker,
    "Actual EPS": actual_eps,
    "Estimated EPS": estimated_eps,
    "Fiscal Quarter": fiscal_period
    })

# %%
newearnings
# Out:
#       Actual EPS  Estimated EPS Fiscal Quarter Ticker
# 0            NaN            NaN           None   XXII
# 1          -0.03            NaN        Q3 2017   XXII
# 2          -0.04            NaN        Q2 2017   XXII
# 3          -0.03            NaN        Q1 2017   XXII
# 4            NaN            NaN           None    FAX
# 5            NaN            NaN           None    FAX
# 6            NaN            NaN           None    FAX
# 7            NaN            NaN           None    FAX
# 8            NaN            NaN           None    IAF
# 9            NaN            NaN           None    IAF
# 10           NaN            NaN           None    IAF
# 11           NaN            NaN           None    IAF
# 12           NaN            NaN           None     CH
# 13           NaN            NaN           None     CH
# 14           NaN            NaN           None     CH
# 15           NaN            NaN           None     CH
# 16           NaN            NaN           None    ABE
# 17           NaN            NaN           None    ABE
# 18           NaN            NaN           None    ABE
# 19           NaN            NaN           None    ABE
# 20           NaN            NaN           None    FCO
# 21           NaN            NaN           None    FCO
# 22           NaN            NaN           None    FCO
# 23           NaN            NaN           None    FCO
# 24           NaN            NaN           None     IF
# 25           NaN            NaN           None     IF
# 26           NaN            NaN           None     IF
# 27           NaN            NaN           None     IF
# 28           NaN            NaN           None    ISL
# 29           NaN            NaN           None    ISL
# ...          ...            ...            ...    ...
# 1214         NaN            NaN           None    ERH
# 1215         NaN            NaN           None    ERH
# 1216         NaN            NaN           None    WRN
# 1217       -0.01          -0.01        Q3 2017    WRN
# 1218       -0.01            NaN        Q2 2017    WRN
# 1219       -0.01            NaN        Q1 2017    WRN
# 1220         NaN            NaN           None    WYY
# 1221         NaN          -0.01        Q3 2017    WYY
# 1222       -0.02          -0.01        Q2 2017    WYY
# 1223       -0.01          -0.01        Q1 2017    WYY
# 1224         NaN            NaN           None    WTT
# 1225         NaN            NaN           None    WTT
# 1226         NaN            NaN           None    WTT
# 1227         NaN            NaN           None    WTT
# 1228         NaN            NaN        Q4 2017   XTNT
# 1229         NaN            NaN        Q3 2017   XTNT
# 1230       -0.54            NaN        Q2 2017   XTNT
# 1231       -0.29            NaN        Q1 2017   XTNT
# 1232         NaN            NaN           None   YUMA
# 1233         NaN            NaN           None   YUMA
# 1234         NaN            NaN           None   YUMA
# 1235         NaN            NaN           None   YUMA
# 1236         NaN            NaN           None   ZDGE
# 1237         NaN            NaN           None   ZDGE
# 1238         NaN            NaN           None   ZDGE
# 1239         NaN            NaN           None   ZDGE
# 1240         NaN            NaN           None    ZOM
# 1241         NaN            NaN           None    ZOM
# 1242         NaN            NaN           None    ZOM
# 1243         NaN            NaN           None    ZOM
#
# [1244 rows x 4 columns]
