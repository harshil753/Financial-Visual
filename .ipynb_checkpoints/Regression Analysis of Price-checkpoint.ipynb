# 1576    82016675     17.36    ACU             0.054395  21.9800  2016-11-30
# 1575    82016675     17.36    ACU             0.054395  25.5700  2016-12-30
# 1574    82016675     17.36    ACU             0.054395  24.3600  2017-01-31
# 1573    82016675     17.36    ACU             0.054395  25.8500  2017-02-28
# 1572    82016675     17.36    ACU             0.054395  28.0100  2017-03-31
# 1571    82016675     17.36    ACU             0.054395  29.0000  2017-04-28
# 1570    82016675     17.36    ACU             0.054395  28.5000  2017-05-31
# 1569    82016675     17.36    ACU             0.054395  28.6000  2017-06-30
# 1568    82016675     17.36    ACU             0.054395  27.6700  2017-07-31
# 1567    82016675     17.36    ACU             0.054395  23.8400  2017-08-31
# 1566    82016675     17.36    ACU             0.054395  23.0000  2017-09-29
# 1565    82016675     17.36    ACU             0.054395  22.5000  2017-10-31
# 1564    82016675     17.36    ACU             0.054395  22.6200  2017-11-30
# 1563    82016675     17.36    ACU             0.054395  23.4000  2017-12-29
# 1562    82016675     17.36    ACU             0.054395  24.2300  2018-01-12
#
#          Open
# 1777   1.6875
# 1776   2.1250
# 1775   2.6250
# 1774   2.5000
# 1773   2.2500
# 1772   3.2500
# 1771   3.0000
# 1770   3.3750
# 1769   3.6250
# 1768   3.2500
# 1767   2.8750
# 1766   2.5625
# 1765   3.3000
# 1764   3.6500
# 1763   2.7500
# 1762   2.9500
# 1761   3.5500
# 1760   3.3500
# 1759   3.3000
# 1758   3.0500
# 1757   3.0500
# 1756   3.1000
# 1755   3.1000
# 1754   3.8000
# 1753   3.7500
# 1752   4.1000
# 1751   4.0000
# 1750   4.1500
# 1749   4.0000
# 1748   3.8000
# ...       ...
# 1591  18.3300
# 1590  17.2500
# 1589  17.2200
# 1588  16.4700
# 1587  17.0400
# 1586  17.0300
# 1585  14.0800
# 1584  15.3000
# 1583  16.5000
# 1582  17.1300
# 1581  18.1200
# 1580  18.7500
# 1579  21.5000
# 1578  20.7000
# 1577  20.8200
# 1576  22.0100
# 1575  22.1500
# 1574  25.7500
# 1573  24.0300
# 1572  25.1700
# 1571  28.2400
# 1570  29.0000
# 1569  28.8700
# 1568  28.0300
# 1567  27.6700
# 1566  23.0000
# 1565  23.0500
# 1564  22.0700
# 1563  22.2600
# 1562  23.2100
#
# [216 rows x 7 columns]

# %%
X = xxii[["Open","PE Ratio","Market Cap", "Year To Date Change"]]
y = xxii["Close"].values.reshape(-1,1)

print(X.shape, y.shape)
# Out:
# (216, 4) (216, 1)

# %%
# Use train_test_split to create training and testing data

### BEGIN SOLUTION
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=28)

### END SOLUTION

# %%
# Create the model using LinearRegression

### BEGIN SOLUTION
from sklearn.linear_model import LinearRegression
model = LinearRegression()
### END SOLUTION

# %%
# Fit the model to the training data and calculate the scores for the training and testing data

### BEGIN SOLUTION
try:
    model.fit(X_train, y_train)
    training_score = model.score(X_train, y_train)
    testing_score = model.score(X_test, y_test)
    print(model.coef_)
except:
    pass
### END SOLUTION 
print(f"Training Score: {training_score}")
print(f"Testing Score: {testing_score}")
# Out:
# [[ 0.99636422  0.          0.          0.        ]]
# Training Score: 0.9793929006663584
# Testing Score: 0.9640545208630964

# %%
# Plot the Residuals for the Training and Testing data

### BEGIN SOLUTION
plt.scatter(model.predict(X_train), model.predict(X_train) - y_train, c="blue", label="Training Data")
plt.scatter(model.predict(X_test), model.predict(X_test) - y_test, c="orange", label="Testing Data")
plt.legend()
plt.hlines(y=0, xmin=y.min(), xmax=y.max())
plt.title("Residual Plot")
### END SOLUTION
plt.show()

# %%
#sklearn linear model (regression)
from sklearn.linear_model import LinearRegression

# %%
# MODEL
# specify model
model = LinearRegression()
model
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
# FIT
#fit data to our model
model.fit(X, y)
model
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
print("m: ", model.coef_)
print("b: ", model.intercept_)
# Out:
# m:  [[-0.00412088]]
# b:  [ 5.3778022]

# %%
x_min = X.min()
x_max = X.max()

y_min = model.predict(x_min)
y_max = model.predict(x_max)

# %%
plt.plot(X, y)
plt.plot([x_min, x_max], [y_min[0], y_max[0]])
plt.gca().invert_xaxis()
plt.xlabel("Date")
plt.ylabel("Price")
plt.show()

# %%
model.score(X, y)
# Out:
# 0.90412250350772405

# %%
# Use sklearn's `train_test_split` to split the data into training and testing

from sklearn.model_selection import train_test_split

# YOUR CODE HERE
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1)

# %%
# Fit the model to the training data. 

# YOUR CODE HERE
model.fit(X_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
from sklearn.metrics import mean_squared_error, r2_score

# YOUR CODE HERE
# Use our model to predict a value
predicted = model.predict(X_test)

# Score the prediction with mse and r2
mse = mean_squared_error(y_test, predicted)
r2 = r2_score(y_test, predicted)

print(f"Mean Squared Error (MSE): {mse}")
print(f"R-squared (R2 ): {r2}")
# Out:
# Mean Squared Error (MSE): 0.12864389382250213
# R-squared (R2 ): 0.6184372124499418
